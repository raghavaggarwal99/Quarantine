# %%
import mglearn
mglearn.plots.plot_kmeans_algorithm()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
# generate some random cluster data
X, y = make_blobs(random_state=170, n_samples=600, centers = 5)
rng = np.random.RandomState(74)
# transform the data to be stretched
transformation = rng.normal(size=(2, 2))
X = np.dot(X, transformation)
# plot
plt.scatter(X[:, 0], X[:, 1])
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()

# %%
# cluster the data into five clusters
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)

kmeans.cluster_centers_
# Out:
# array([[  5.75329493,  -6.37263232],
#        [ -2.53111374,   0.89260335],
#        [  1.0156281 ,  -0.86236281],
#        [  6.95695111, -11.38142848],
#        [ -3.41920423,   3.14557588]])

# %%
kmeans.labels_
# Out:
# array([4, 0, 3, 0, 0, 4, 0, 2, 0, 1, 4, 1, 0, 1, 3, 3, 2, 2, 4, 0, 1, 2,
#        3, 3, 2, 4, 3, 0, 2, 1, 4, 0, 4, 3, 3, 0, 0, 3, 2, 4, 0, 4, 2, 3,
#        1, 2, 0, 0, 2, 3, 2, 3, 2, 0, 4, 0, 1, 1, 1, 0, 0, 4, 4, 1, 0, 4,
#        4, 1, 1, 1, 3, 2, 0, 3, 4, 1, 3, 3, 1, 1, 4, 0, 4, 0, 4, 2, 0, 4,
#        2, 4, 1, 3, 2, 0, 0, 2, 0, 2, 0, 2, 0, 1, 2, 2, 0, 3, 4, 3, 0, 2,
#        1, 2, 2, 2, 2, 2, 3, 1, 2, 4, 0, 3, 3, 4, 1, 0, 4, 3, 2, 3, 2, 3,
#        2, 2, 1, 2, 3, 4, 4, 2, 4, 2, 3, 1, 3, 2, 0, 0, 3, 3, 0, 4, 0, 1,
#        3, 2, 3, 1, 4, 0, 4, 2, 4, 2, 0, 3, 3, 1, 1, 3, 1, 1, 2, 3, 1, 0,
#        3, 2, 1, 4, 0, 2, 4, 1, 4, 0, 1, 2, 1, 4, 2, 0, 4, 0, 4, 4, 4, 4,
#        3, 4, 4, 2, 3, 1, 2, 2, 1, 1, 2, 1, 1, 3, 3, 2, 1, 0, 1, 1, 2, 1,
#        2, 1, 1, 0, 2, 1, 2, 3, 3, 2, 3, 4, 0, 3, 1, 1, 4, 4, 2, 3, 4, 3,
#        1, 4, 3, 1, 0, 1, 4, 0, 0, 4, 3, 4, 0, 0, 4, 1, 0, 0, 1, 4, 4, 0,
#        4, 3, 4, 2, 3, 1, 1, 3, 1, 2, 3, 4, 2, 4, 1, 4, 3, 0, 3, 3, 3, 4,
#        2, 1, 3, 2, 0, 0, 0, 3, 0, 2, 0, 2, 4, 0, 1, 2, 1, 1, 0, 0, 4, 0,
#        3, 4, 1, 4, 2, 0, 0, 1, 4, 4, 0, 4, 0, 3, 0, 0, 2, 3, 0, 2, 2, 0,
#        4, 3, 1, 4, 1, 4, 3, 3, 1, 4, 1, 3, 1, 2, 4, 3, 3, 3, 2, 0, 1, 3,
#        3, 1, 4, 0, 1, 1, 1, 3, 0, 0, 1, 1, 2, 3, 0, 0, 1, 4, 3, 0, 0, 0,
#        3, 4, 0, 2, 3, 0, 3, 0, 1, 4, 2, 1, 2, 0, 3, 3, 2, 4, 3, 2, 2, 1,
#        1, 2, 0, 0, 4, 1, 4, 2, 4, 2, 4, 2, 3, 2, 2, 4, 0, 1, 4, 1, 1, 4,
#        2, 1, 0, 0, 4, 2, 1, 3, 3, 4, 0, 2, 3, 1, 3, 4, 3, 2, 4, 3, 0, 4,
#        1, 2, 3, 1, 1, 1, 0, 1, 4, 1, 1, 3, 3, 1, 2, 3, 3, 4, 2, 3, 4, 3,
#        3, 1, 0, 2, 1, 2, 1, 1, 3, 3, 3, 4, 1, 2, 2, 2, 0, 0, 2, 2, 2, 1,
#        1, 2, 4, 2, 3, 0, 4, 1, 3, 4, 1, 4, 0, 0, 2, 3, 4, 1, 4, 3, 4, 2,
#        1, 4, 0, 0, 3, 0, 0, 2, 3, 0, 3, 4, 1, 1, 0, 3, 3, 2, 0, 0, 0, 3,
#        3, 1, 4, 3, 3, 4, 0, 3, 4, 2, 4, 4, 2, 2, 4, 4, 2, 1, 2, 0, 4, 4,
#        3, 1, 4, 0, 0, 3, 1, 2, 2, 3, 1, 2, 3, 3, 4, 2, 1, 1, 4, 0, 1, 0,
#        3, 4, 1, 4, 4, 1, 2, 1, 3, 0, 2, 0, 2, 4, 0, 4, 4, 1, 1, 0, 1, 4,
#        2, 1, 3, 4, 3, 0], dtype=int32)

# %%
sample_test=np.array([-3.0,-3.0])
second_test=sample_test.reshape(1, -1)
kmeans.predict(second_test)
# Out:
# array([1], dtype=int32)

# %%
y_pred = kmeans.predict(X)
# plot the cluster assignments and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0],   
            kmeans.cluster_centers_[:, 1],
            marker='^', 
            c=[0, 1, 2, 3, 4], 
            s=100, 
            linewidth=2,
            cmap="plasma")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0, 0.5, 'Feature 1')
